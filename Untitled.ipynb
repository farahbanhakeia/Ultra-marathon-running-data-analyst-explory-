# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# C:\Users\farah\AppData\Local\Temp\ipykernel_7928\287130472.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of          Year of event Event dates                                Event name  \
# 0                 2018  06.01.2018                       Selva Costera (CHI)
# 1                 2018  06.01.2018                       Selva Costera (CHI)
# 2                 2018  06.01.2018                       Selva Costera (CHI)
# 3                 2018  06.01.2018                       Selva Costera (CHI)
# 4                 2018  06.01.2018                       Selva Costera (CHI)
# ...                ...         ...                                       ...
# 7461190           1995  00.00.1995                 La SainteLyon 65 km (FRA)
# 7461191           1995  00.00.1995                 La SainteLyon 65 km (FRA)
# 7461192           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461193           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461194           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
#
# ...

# %%
df.isnull().sum()
# Out:
# Year of event                      0
# Event dates                        0
# Event name                         0
# Event distance/length           1053
# Event number of finishers          0
# Athlete performance                2
# Athlete club                 2826524
# Athlete country                    3
# Athlete year of birth         588161
# Athlete gender                     7
# Athlete age category          584938
# Athlete average speed            224
# Athlete ID                         0
# dtype: int64

# %%
df.shape
# Out:
# (7461195, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %% [markdown]
# ### Clean data

# %%
df["Event distance/length"].value_counts()
# Out:
# Event distance/length
# 50km              1522609
# 100km              951742
# 50mi               352181
# 56km               333253
# 87km               212062
#                    ...
# 61.15km                 1
# 27:30h                  1
# 178km/2Etappen          1
# 740km                   1
# 158.5mi                 1
# Name: count, Length: 2159, dtype: int64

# %%
# combien 50k/50mi 
df[df["Event distance/length"].isin(['50km','50mi'])]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df[df["Event distance/length"].isin(['50km','50mi']) & (df['Year of event'] ==2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...

# %%
df[df['Event name'] == 'Everglades 50 Mile Ultra Run (USA)']
# Out:
#          Year of event Event dates                          Event name  \
# 51923             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51924             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51925             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51926             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51927             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# ...                ...         ...                                 ...
# 6417091           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6417092           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6417093           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6417094           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6417095           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df[df['Event name'] == 'Everglades 50 Mile Ultra Run (USA)']['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)
# Out:
# 51923      USA
# 51924      USA
# 51925      USA
# 51926      USA
# 51927      USA
#           ...
# 6417091    USA
# 6417092    USA
# 6417093    USA
# 6417094    USA
# 6417095    USA
# Name: Event name, Length: 338, dtype: object

# %%
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
## cobine all filter togethers 
df2=df[ df["Event distance/length"].isin(['50km','50mi']) & (df['Year of event'] == 2020) & ( df['Event name'] .str.split('(').str.get(1) .str.split(')').str.get(0) == 'USA' ) ]

# %%
df2.head(5)
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance  \
# 2539945                         20           3:17:55 h
# 2539946                         20           4:02:32 h
# 2539947                         20           4:07:57 h
# 2539948                         20           4:22:02 h
# ...

# %%
df2.shape
# Out:
# (26090, 13)

# %%
## Remose (USA) from event name 
df2['Event name']=df2['Event name'].str.split('(').str.get(0)
# Out:
# C:\Users\farah\AppData\Local\Temp\ipykernel_7928\2709155952.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Event name']=df2['Event name'].str.split('(').str.get(0)

# %%
df2.head(5)
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20           3:17:55 h
# 2539946                  50km                         20           4:02:32 h
# 2539947                  50km                         20           4:07:57 h
# 2539948                  50km                         20           4:22:02 h
# 2539949                  50km                         20           4:27:34 h
#
# ...

# %%
#clean  up  the athlete age
df2['athlete_age']=2020-df2['Athlete year of birth']
# Out:
# C:\Users\farah\AppData\Local\Temp\ipykernel_7928\758906450.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['athlete_age']=2020-df2['Athlete year of birth']

# %%
# remove h from athelate performance
df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# C:\Users\farah\AppData\Local\Temp\ipykernel_7928\4201673505.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)

# %%
df2.head(4)
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
#
#                Athlete club Athlete country  Athlete year of birth  \
# 2539945  *Normandy Park, WA             USA                 1991.0
# ...

# %%
# drop some columns
df2=df2.drop(['Athlete club','Athlete country','Athlete year of birth','Athlete age category'],axis=1)

# %%
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
# ...

# %%
#clean the null values
df2.isna().sum()
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete gender                 0
# Athlete average speed          0
# Athlete ID                     0
# athlete_age                  233
# dtype: int64

# %%
df2=df2.dropna()

# %%
df2.isna().sum()
# Out:
# Year of event                0
# Event dates                  0
# Event name                   0
# Event distance/length        0
# Event number of finishers    0
# Athlete performance          0
# Athlete gender               0
# Athlete average speed        0
# Athlete ID                   0
# athlete_age                  0
# dtype: int64

# %%
df2.shape
# Out:
# (25857, 10)

# %%
df2.duplicated().sum() # nombre doublons
# Out:
# np.int64(0)

# %%
# fix the data type

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                     int64
# athlete_age                  float64
# dtype: object

# %%
df2['athlete_age']=df2['athlete_age'].astype(int)

# %%
df2['Athlete average speed']=df2['Athlete average speed'].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# athlete_age                    int64
# dtype: object

# %%
#rename some colomns

# %%
df2=df2.rename(columns={ 'Year of event':'year',
                        'Event dates':'race_day',
                        'Event name':'race_name',
                        'Event distance/length':'race_length',
                        'Event number of finishers':'race_number_of_finishers',
                        'Athlete performance':'athlete_performance',
                        'Athlete gender':'gender',
                        'Athlete average speed':'athlete_average_speed',
                        'Athlete ID':'id',
                        'Athlete_age':'age'})

# %%
df2.dtypes
# Out:
# year                          int64
# race_day                     object
# race_name                    object
# race_length                  object
# race_number_of_finishers      int64
# athlete_performance          object
# gender                       object
# athlete_average_speed       float64
# id                            int64
# athlete_age                   int64
# dtype: object

# %%
 ### Order the comuns

# %%
df3 = df2[['race_day',
           'race_name',
           'race_length',
           'race_number_of_finishers',
           'id',
           'gender',
           'athlete_age',
           'athlete_performance',
            'athlete_average_speed']]

# %%
df3.head()
# Out:
#            race_day                                 race_name race_length  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition         50km
#
#          race_number_of_finishers      id gender  athlete_age  \
# 2539945                        20   71287      M           29
# 2539946                        20  629508      M           39
# 2539947                        20   64838      M           21
# 2539948                        20  704450      M           37
# 2539949                        20  810281      M           43
#
#         athlete_performance  athlete_average_speed
# 2539945             3:17:55                 15.158
# ...

# %%
df3[df3['race_name']=='Everglades 50 Mile Ultra Run ']
# Out:
#            race_day                      race_name race_length  \
# 2591476  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591477  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591478  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591479  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591480  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591481  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591482  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591483  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591484  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591485  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591486  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591487  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591488  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591489  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# ...

# %%
####

# %%
sns.histplot(df3['race_length'])
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.histplot(df3,x='race_length',hue='gender')
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.displot(df3[df3['race_length'] == '50mi']['athlete_age'])

# %%
plt.figure(figsize=(8,5))
sns.histplot(df3['athlete_age'], bins=15, kde=True)
plt.title("Distribution de l'âge des athlètes")
plt.xlabel("Âge")
plt.ylabel("Nombre d'athlètes")
plt.show()

# %%
df3.dtypes
# Out:
# race_day                     object
# race_name                    object
# race_length                  object
# race_number_of_finishers      int64
# id                            int64
# gender                       object
# athlete_age                   int64
# athlete_performance          object
# athlete_average_speed       float64
# dtype: object

# %%
sns.histplot(df3,x='athlete_average_speed',hue='gender')
# Out:
# <Axes: xlabel='athlete_average_speed', ylabel='Count'>

# %%
sns.displot(df3[df3['race_length'] =='50km']['athlete_average_speed'],  kde=True,  bins=20)

# %%
sns.boxplot(x='gender', y='athlete_average_speed', data=df3)
plt.title("Vitesse moyenne par genre")
plt.xlabel("Genre")
plt.ylabel("Vitesse moyenne (km/h)")
plt.show()

# %%
sns.barplot(x='race_length', y='race_number_of_finishers', data=df3, ci=None)
plt.title("Nombre de finishers par longueur de course")
plt.xlabel("Longueur de la course")
plt.ylabel("Nombre de finishers")
plt.show()
# Out:
# C:\Users\farah\AppData\Local\Temp\ipykernel_7928\696248712.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='race_length', y='race_number_of_finishers', data=df3, ci=None)

# %%
sns.displot(df3[df3['race_length'] == '50km']['athlete_average_speed'], kde=True, bins=20)
plt.title("Distribution de la vitesse moyenne pour les courses de 50km")
plt.xlabel("Vitesse moyenne (km/h)")
plt.ylabel("Nombre d'athlètes")
plt.show()

# %%
sns.displot(df3[df3['race_length'] == '50mi']['athlete_average_speed'], kde=True, bins=20)
plt.title("Distribution de la vitesse moyenne pour les courses de 50mi")
plt.xlabel("Vitesse moyenne (km/h)")
plt.ylabel("Nombre d'athlètes")
plt.show()

# %%
### convert HH:MM::SS en H

# %%
df3['race_time_hours'] = pd.to_timedelta(df3['athlete_average_speed']).dt.total_seconds() / 3600

# %%
sns.histplot(df3['race_time_hours'], bins=30, kde=True)
plt.title("Distribution du temps des athlètes (en heures)")
plt.xlabel("Temps (heures)")
plt.ylabel("Nombre d'athlètes")
plt.show()
